# %% [markdown]
# Cleaning data in Python:
# -----------------------
#        - .NaN -- not a number
#        - .working with duplicates and missing values
#               - .isnull()
#               - .notnull()
#               - .dropna()
#               - .fillna()
#               - .replace()
#        - .Which values should be replaced in place of missing values is based on data identifying and eliminating outliers

# %% [markdown]
# Identifying and eliminating outliers:
# ---------------------------------------------------
#          - .outliers are observations that are significantly different from other data points
#          - .outliers can affect the training process of a machine learning algorithm, resulting in a loss of accuracy
#          - .IQR = Q3(quantile(0.75)) - Q1(quantile(0.25))

# %%
import numpy as np
import pandas as pd

# %%
d=pd.read_csv("employee.csv")
d
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
d.shape
# Out:
# (1000, 8)

# %%
d.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
d.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
d.notnull().sum()
# Out:
# First Name            933
# Gender                855
# Start Date           1000
# Last Login Time      1000
# Salary               1000
# Bonus %              1000
# Senior Management     933
# Team                  957
# dtype: int64

# %%
d.dropna().shape
# Out:
# (764, 8)

# %%
d.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
d["Gender"].isnull().sum()
# Out:
# 145

# %%
pd.isnull(d["Gender"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Gender, Length: 1000, dtype: bool

# %% [markdown]
# Filling missing values with meaningful data:
# ------------------------------------------------------------
# -   .mean
# -    median
# -    mode
# -    constant

# %%
d["Gender"].fillna("not available").head(100)
# Out:
# 0              Male
# 1              Male
# 2            Female
# 3              Male
# 4              Male
#           ...
# 95           Female
# 96           Female
# 97    not available
# 98           Female
# 99             Male
# Name: Gender, Length: 100, dtype: object

# %%
d["Gender"].fillna(method="pad").head(100)
# Out:
# 0       Male
# 1       Male
# 2     Female
# 3       Male
# 4       Male
#        ...
# 95    Female
# 96    Female
# 97    Female
# 98    Female
# 99      Male
# Name: Gender, Length: 100, dtype: object

# %%
d["Gender"].fillna(method="bfill")
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
d["Gender"].fillna(0)
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995         0
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
d.replace(to_replace="Female",value=-1)
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas   Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     -1   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry   Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry   Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...    ...         ...             ...     ...      ...
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip   Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell   Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry   Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert   Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
d
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# #### dropping duplicate values

# %%
d1={"key1":[95,95,45,np.nan,25],
   "key2":[100,25,14,np.nan,28],
   "key3":[88,65,22,88,np.nan]}
df2=pd.DataFrame(d1)
df2
# Out:
#    key1   key2  key3
# 0  95.0  100.0  88.0
# 1  95.0   25.0  65.0
# 2  45.0   14.0  22.0
# 3   NaN    NaN  88.0
# 4  25.0   28.0   NaN

# %%
df2.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df2.drop_duplicates()
# Out:
#    key1   key2  key3
# 0  95.0  100.0  88.0
# 1  95.0   25.0  65.0
# 2  45.0   14.0  22.0
# 3   NaN    NaN  88.0
# 4  25.0   28.0   NaN

# %%
df3={"key1":[95,75,75,np.nan,65,95],
   "key2":[85,75,75,np.nan,65,95],
   "key3":[88,75,75,np.nan,65,95]}
df4=pd.DataFrame(df3)
df4
# Out:
#    key1  key2  key3
# 0  95.0  85.0  88.0
# 1  75.0  75.0  75.0
# 2  75.0  75.0  75.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0
# 5  95.0  95.0  95.0

# %%
df4.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df4.drop_duplicates()
# Out:
#    key1  key2  key3
# 0  95.0  85.0  88.0
# 1  75.0  75.0  75.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0
# 5  95.0  95.0  95.0

# %%
df5={"key1":[95,75,75,np.nan,65,95],
   "key2":[95,75,75,np.nan,65,65],
   "key3":[88,75,85,np.nan,65,95]}
df6=pd.DataFrame(df5)
df6
# Out:
#    key1  key2  key3
# 0  95.0  95.0  88.0
# 1  75.0  75.0  75.0
# 2  75.0  75.0  85.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0
# 5  95.0  65.0  95.0

# %%
df6.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df6.drop_duplicates(subset="key2")
# Out:
#    key1  key2  key3
# 0  95.0  95.0  88.0
# 1  75.0  75.0  75.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0

# %%
df6.drop_duplicates(subset=["key2","key3"])
# Out:
#    key1  key2  key3
# 0  95.0  95.0  88.0
# 1  75.0  75.0  75.0
# 2  75.0  75.0  85.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0
# 5  95.0  65.0  95.0

# %%
df7={"key1":[95,75,75,np.nan,65,95],
   "key2":[95,75,75,np.nan,65,65],
   "key3":[95,75,75,np.nan,65,95]}
df8=pd.DataFrame(df7)
df8
# Out:
#    key1  key2  key3
# 0  95.0  95.0  95.0
# 1  75.0  75.0  75.0
# 2  75.0  75.0  75.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0
# 5  95.0  65.0  95.0

# %%
df8.drop_duplicates(subset=["key2","key3"])
# Out:
#    key1  key2  key3
# 0  95.0  95.0  95.0
# 1  75.0  75.0  75.0
# 3   NaN   NaN   NaN
# 4  65.0  65.0  65.0
# 5  95.0  65.0  95.0

# %% [markdown]
# #####  Identifying and Eliminating outliers

# %%
import matplotlib.pyplot as plt

# %%
adv=pd.read_csv("Advertising.csv")
adv.head(11)
# Out:
#        TV  radio  newspaper  sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3    9.3
# 3   151.5   41.3       58.5   18.5
# 4   180.8   10.8       58.4   12.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   10.6
# 10   66.1    5.8       24.2    8.6

# %%
adv.plot(kind="box")
plt.show()

# %%
Q3=adv.quantile(0.75)
Q1=adv.quantile(0.25)
IQR=Q3-Q1
IQR
# Out:
# TV           144.450
# radio         26.550
# newspaper     32.350
# sales          7.025
# dtype: float64

# %%
fliter_data=adv[((adv<(Q1-1.5*IQR))|(adv>(Q3+1.5*IQR))).any(axis=1)]
fliter_data
# Out:
#         TV  radio  newspaper  sales
# 16    67.8   36.6      114.0   12.5
# 101  296.4   36.3      100.9   23.8

# %%
fliter_data=adv [~((adv<(Q1 - 1.5 * IQR))|(adv>(Q3 + 1.5 * IQR))).any(axis=1)]
fliter_data
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [198 rows x 4 columns]

# %%
fliter_data.plot(kind="box")
plt.show()
